# %%
# !pip3 install pandas

# %%
import pandas as pd 
import numpy

# %%
df = pd.read_csv('PMI1_SOBPMI_log_20220725T150000_1400-1500.log.gz', compression= 'gzip' , header=0, sep=' ', quotechar='"', error_bad_lines=False)

# %%
df.columns

# %%
import gzip
import csv 
with gzip.open("PMI1_SOBPMI_log_20220725T150000_1400-1500.log.gz", "b") as f:
    reader = csv.DictReader((l.replace('\0', '') for l in f))

# %%
df = pd.read_csv('PMI1_SOBPMI_log_20220725T150000_1400-1500.log.gz', delimiter='\t+', encoding='utf-8', on_bad_lines='skip', compression='gzip', engine='python')

# %%
asd = df[0][0]

# %%
df = pd.DataFrame(df)

# %%
df.value_counts()

# %%
import glob 
import pandas as pd 

file_path= '*.log' 

def read_logs(path):
    epex_log = []
    log_files = glob.glob(path)
    for filename in log_files:
        with open(filename, 'r') as f:
            for line in f:
                if """EPEX""" in line:
                    epex_log.append(line)
    

    return epex_log


epex_log = read_logs(file_path)





epex_log = pd.DataFrame(epex_log)
print(epex_log.count())
epex_log.to_csv('epex_pmi_logs.csv')
# Out:
# 0    1480
# dtype: int64

# %%
file = '*.log'
log_files = glob.glob(file)
epex_log = []

for filename in log_files:
    with open(filename, 'r') as f:
        for line in f:
            if """EPEX""" in line:
                print(epex_log.append(line))

epex_log = pd.DataFrame(epex_log)
print(epex_log.count())
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
epex_log.to_csv('EPEX.csv')

# %%
import pandas as pd 
import glob 

file = '*.log'
log_files = glob.glob(file)

for filename in log_files:
    strings = ('OrdrReq', 'FullOrdrCaptureReq')

    with open(filename, 'r') as f:
        for line in f:
            if  (s in line for s in strings):
                print((line))

#epex_log = pd.DataFrame(epex_log)
#print(epex_log.count())
# Out:
# <OrdrReq xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" acctId="BG-GME--------01" xmlns="http://www.deutsche-boerse.com/m7/v1">
#
# ...
