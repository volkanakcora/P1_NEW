# %%
import pandas as pd 
import numpy as np
import gzip

# %%
xferlog = pd.read_csv('xferlog-20230814.gz', compression='gzip', header=0, sep=' ', quotechar='"', error_bad_lines=False)
haproxy = pd.read_csv('haproxy.gz', compression='gzip', header=0, sep=' ', quotechar='"', error_bad_lines=False)
# Out:
# <ipython-input-112-54e4ba56d4ca>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   xferlog = pd.read_csv('xferlog-20230814.gz', compression='gzip', header=0, sep=' ', quotechar='"', error_bad_lines=False)
# <ipython-input-112-54e4ba56d4ca>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   haproxy = pd.read_csv('haproxy.gz', compression='gzip', header=0, sep=' ', quotechar='"', error_bad_lines=False)
# Skipping line 42544: expected 14 fields, saw 34
# Skipping line 43992: expected 14 fields, saw 30
# Skipping line 44064: expected 14 fields, saw 34
# Skipping line 44457: expected 14 fields, saw 30

# %%
haproxy.head(10)
# Out:
#    Aug  17  03:10:01  localhost  haproxy[1174]:   185.81.228.10:32065  \
# 0  Aug  17  03:10:01  localhost  haproxy[1174]:  195.254.209.13:52161
# 1  Aug  17  03:10:02  localhost  haproxy[1174]:  195.254.158.52:41130
# 2  Aug  17  03:10:03  localhost  haproxy[1174]:     5.32.184.10:52199
# 3  Aug  17  03:10:03  localhost  haproxy[1174]:  195.225.127.58:26156
# 4  Aug  17  03:10:04  localhost  haproxy[1174]:   195.225.127.58:7766
# 5  Aug  17  03:10:06  localhost  haproxy[1174]:  85.237.226.122:65147
# 6  Aug  17  03:10:10  localhost  haproxy[1174]:  91.209.155.250:46698
# 7  Aug  17  03:10:11  localhost  haproxy[1174]:  91.208.150.250:11181
# 8  Aug  17  03:10:13  localhost  haproxy[1174]:  85.237.226.122:47998
# 9  Aug  17  03:10:14  localhost  haproxy[1174]:  195.254.209.13:52179
#
#    [17/Aug/2023:03:10:00.322]  sftp  sftp/sftp-3    1/0/848    3424  --  \
# 0  [17/Aug/2023:03:09:48.851]  sftp  sftp/sftp-3  1/0/12843  211600  --
# 1  [17/Aug/2023:03:10:01.360]  sftp  sftp/sftp-1    1/0/719    3960  --
# 2  [17/Aug/2023:03:10:02.780]  sftp  sftp/sftp-1    1/0/575    5576  --
# 3  [17/Aug/2023:03:10:02.730]  sftp  sftp/sftp-3    1/0/775    3624  --
# 4  [17/Aug/2023:03:10:03.529]  sftp  sftp/sftp-1    1/0/769    3624  --
# 5  [17/Aug/2023:03:10:06.969]  sftp  sftp/sftp-3      1/0/9     848  --
# 6  [17/Aug/2023:03:10:09.869]  sftp  sftp/sftp-1   1/0/1002    3344  --
# 7  [17/Aug/2023:03:10:10.249]  sftp  sftp/sftp-3    1/0/820    3344  --
# 8  [17/Aug/2023:03:10:13.573]  sftp  sftp/sftp-1     1/0/23     848  CD
# 9  [17/Aug/2023:03:10:01.724]  sftp  sftp/sftp-3  1/0/13202  211600  --
#
#    8/8/8/2/0  0/0
# 0  8/8/8/1/0  0/0
# 1  8/8/8/2/0  0/0
# 2  9/9/9/2/0  0/0
# 3  8/8/8/2/0  0/0
# 4  8/8/8/2/0  0/0
# 5  8/8/8/2/0  0/0
# 6  9/9/9/2/0  0/0
# 7  8/8/8/2/0  0/0
# 8  8/8/8/2/0  0/0
# 9  7/7/7/1/0  0/0

# %%
xferlog.head(10)
# Out:
#    Sun  Aug  13  23:25:48  2023  0  10.136.152.254  4877  \
# 0  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1136
# 1  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1137
# 2  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1137
# 3  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1137
# 4  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1137
# 5  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1137
# 6  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1137
# 7  Sun  Aug  13  23:25:51  2023  0  10.136.152.254  1136
# 8  Sun  Aug  13  23:25:52  2023  0  10.136.152.254  1137
# 9  Sun  Aug  13  23:25:52  2023  0  10.136.152.254  1137
#
#   /opt/data01/xbid_elering_prod/IN/cmi/A13_EE_12082023T155702S225748.xml  b  \
# 0  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_7...                      b
# 1  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_9...                      b
# 2  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_6...                      b
# 3  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_c...                      b
# 4  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_7...                      b
# 5  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_3...                      b
# 6  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_9...                      b
# 7  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_9...                      b
# 8  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_6...                      b
# 9  /opt/data01/xbid_np_prod/IN/cmi/20230813_ACK_f...                      b
#
#    _  i  r xbid_elering_prod  sftp  0.1  *  c
# 0  _  i  r      xbid_np_prod  sftp    0  *  c
# 1  _  i  r      xbid_np_prod  sftp    0  *  c
# 2  _  i  r      xbid_np_prod  sftp    0  *  c
# 3  _  i  r      xbid_np_prod  sftp    0  *  c
# 4  _  i  r      xbid_np_prod  sftp    0  *  c
# 5  _  i  r      xbid_np_prod  sftp    0  *  c
# 6  _  i  r      xbid_np_prod  sftp    0  *  c
# 7  _  i  r      xbid_np_prod  sftp    0  *  c
# 8  _  i  r      xbid_np_prod  sftp    0  *  c
# 9  _  i  r      xbid_np_prod  sftp    0  *  c

# %% [markdown]
# # HPROXY

# %%
## renaming the columsn
haproxy = haproxy.rename(columns={"Sun":"Day","Aug":"Month", "17":"Day","03:10:01":"time", "sftp/sftp-3":"sftp_channel", "185.81.228.10:32065":"ip"}, index={8:"sftp_channel"})

# %%
haproxy.head(5)
# Out:
#   Month  Day      time  localhost  haproxy[1174]:                    ip  \
# 0   Aug   17  03:10:01  localhost  haproxy[1174]:  195.254.209.13:52161
# 1   Aug   17  03:10:02  localhost  haproxy[1174]:  195.254.158.52:41130
# 2   Aug   17  03:10:03  localhost  haproxy[1174]:     5.32.184.10:52199
# 3   Aug   17  03:10:03  localhost  haproxy[1174]:  195.225.127.58:26156
# 4   Aug   17  03:10:04  localhost  haproxy[1174]:   195.225.127.58:7766
#
#    [17/Aug/2023:03:10:00.322]  sftp sftp_channel    1/0/848    3424  --  \
# 0  [17/Aug/2023:03:09:48.851]  sftp  sftp/sftp-3  1/0/12843  211600  --
# 1  [17/Aug/2023:03:10:01.360]  sftp  sftp/sftp-1    1/0/719    3960  --
# 2  [17/Aug/2023:03:10:02.780]  sftp  sftp/sftp-1    1/0/575    5576  --
# 3  [17/Aug/2023:03:10:02.730]  sftp  sftp/sftp-3    1/0/775    3624  --
# 4  [17/Aug/2023:03:10:03.529]  sftp  sftp/sftp-1    1/0/769    3624  --
#
#    8/8/8/2/0  0/0
# 0  8/8/8/1/0  0/0
# 1  8/8/8/2/0  0/0
# 2  9/9/9/2/0  0/0
# 3  8/8/8/2/0  0/0
# 4  8/8/8/2/0  0/0

# %% [markdown]
# - below we see how many request went to each channel on 17/18

# %%
haproxy.groupby(["sftp_channel","Day"]).agg({"ip":"count"}) ## This way of table shows the profitability
# Out:
#                      ip
# sftp_channel Day
# sftp/<NOSRV> 17     600
#              18      95
# sftp/sftp-1  17   13172
#              18    3160
# sftp/sftp-3  17    8429
#              18     693
# sftp/sftp-5  17   52348
#              18    3785

# %% [markdown]
# ## clean the data and get only the ips:

# %%
haproxy['ip'] = haproxy['ip'].str.split(":", expand=True)[0]

# %%
haproxy = haproxy[["Month","Day","time","ip","sftp_channel"]]

# %%
# get the minutes:
haproxy['minutes'] = haproxy['time'].apply(lambda x: x[3:5])

# %%
haproxy['time'] = haproxy['time'].apply(lambda x:x[0:2])  ##only get the hours

# %% [markdown]
# ## Below we can clearly see the number of IPs went through haproxy.

# %%
haproxy['ip'].value_counts()
# Out:
# 213.151.236.158    9164
# 195.225.127.58     9110
# 91.209.155.250     8128
# 5.32.184.10        7593
# 89.111.92.21       6770
# 185.81.228.10      5866
# 195.254.209.13     4325
# 85.237.226.122     4207
# 91.234.142.10      2784
# 81.89.18.164       2760
# 193.180.216.132    2690
# 91.208.150.250     2622
# 195.47.226.1       2595
# 195.254.158.52     1723
# 20.238.241.203     1436
# 78.28.114.85       1408
# 109.235.136.244    1371
# 185.165.105.254    1256
# 195.29.242.158     1154
# 193.108.204.83     1151
# 195.47.233.240     1112
# 193.148.125.75     1034
# 195.234.135.131     851
# 193.242.255.201     359
# 85.239.110.39       287
# 91.234.143.4        287
# 193.110.14.107      156
# 194.140.78.155       50
# 194.224.33.131       14
# 18.158.210.144       11
# 194.224.33.153        7
# 194.50.11.43          1
# Name: ip, dtype: int64

# %% [markdown]
# ## how many request forwarded to which sftp server

# %%
import seaborn as sns
haproxy.groupby("sftp_channel").agg({"ip":"count"}).plot.barh();

# %% [markdown]
# ## issue occured exactly 07:01 on com5 host, therefore we need to check the connections exactly before it.

# %%
data_frame_1 = haproxy[(haproxy["time"] < "08")] #data before 8 am

# %%
data_frame_2 = data_frame_1[(data_frame_1["Day"] == 17)] #data on 17th

# %%
data_frame_3 =  data_frame_2[(data_frame_2['sftp_channel'] == "sftp/sftp-5")] #sftp channel 5

# %%
data_frame_3 # now we have the data for our investigation
# Out:
#       Month  Day time               ip sftp_channel minutes
# 22      Aug   17   03   193.108.204.83  sftp/sftp-5      10
# 26      Aug   17   03  109.235.136.244  sftp/sftp-5      10
# 27      Aug   17   03   91.209.155.250  sftp/sftp-5      10
# 45      Aug   17   03     78.28.114.85  sftp/sftp-5      10
# 60      Aug   17   03   193.148.125.75  sftp/sftp-5      11
# ...     ...  ...  ...              ...          ...     ...
# 26904   Aug   17   07    185.81.228.10  sftp/sftp-5      59
# 26905   Aug   17   07    185.81.228.10  sftp/sftp-5      59
# 26906   Aug   17   07     89.111.92.21  sftp/sftp-5      59
# 26907   Aug   17   07     89.111.92.21  sftp/sftp-5      59
# 26908   Aug   17   07     89.111.92.21  sftp/sftp-5      59
#
# [20316 rows x 6 columns]

# %%
data_frame_3['ip'].value_counts()  ## Here actually we can see before the 7 am, the IPs created the most connection:
# Out:
# 213.151.236.158    8763
# 89.111.92.21       3250
# 5.32.184.10        1148
# 195.225.127.58     1001
# 91.209.155.250      882
# 185.81.228.10       662
# 195.254.209.13      570
# 91.234.142.10       568
# 193.108.204.83      514
# 85.237.226.122      440
# 193.148.125.75      343
# 91.208.150.250      300
# 81.89.18.164        273
# 195.47.226.1        246
# 195.234.135.131     194
# 195.254.158.52      172
# 185.165.105.254     164
# 78.28.114.85        157
# 20.238.241.203      154
# 195.47.233.240      129
# 109.235.136.244     117
# 193.180.216.132      88
# 195.29.242.158       85
# 193.242.255.201      42
# 194.140.78.155       24
# 85.239.110.39        13
# 194.224.33.131       11
# 91.234.143.4          6
# Name: ip, dtype: int64

# %% [markdown]
# ###  Here actually we can see before the 7 am, the IPs created the most connection:
# - 213.151.236.158    3736
# - 89.111.92.21       1016
# - 195.225.127.58      625

# %% [markdown]
# ## I would like to see the time stamps of the our culpit ipS, for the day of17th:
#
# ### ATTRIBUTES:
# - TIME= shows us the every hours, and rest of the values is in count format, so every IP's requests over time(hours) of 17TH

# %% [markdown]
# # for the IP: 213.151.236.158

# %%
data_for_requests_for_213_151_236_158 = haproxy[haproxy['ip']=="213.151.236.158"]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['Day']==17]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['sftp_channel']=="sftp/sftp-5"]

# %%
data_for_requests_for_213_151_236_158.groupby(["time"]).count() ## this IP sent us 10k request mostly around 6-7 am., and nothing after 8am
# Out:
#       Month   Day    ip  sftp_channel  minutes
# time
# 03       27    27    27            27       27
# 04       36    36    36            36       36
# 05       35    35    35            35       35
# 06     3638  3638  3638          3638     3638
# 07     5027  5027  5027          5027     5027
# 08       39    39    39            39       39
# 10       10    10    10            10       10
# 11       15    15    15            15       15
# 12       24    24    24            24       24

# %% [markdown]
# # for the IP: 195.225.127.58

# %%
data_for_requests_for_195_225_127_58 = haproxy[haproxy['ip']=="195.225.127.58"]
data_for_requests_for_195_225_127_58 = data_for_requests_for_195_225_127_58[data_for_requests_for_195_225_127_58["Day"] == 17]
data_for_requests_for_195_225_127_58 = data_for_requests_for_195_225_127_58[data_for_requests_for_195_225_127_58["sftp_channel"] == "sftp/sftp-5"]

# %%
data_for_requests_for_195_225_127_58.groupby(["time"]).count()
# Out:
#       Month  Day   ip  sftp_channel  minutes
# time
# 03       80   80   80            80       80
# 04      136  136  136           136      136
# 05      135  135  135           135      135
# 06      274  274  274           274      274
# 07      376  376  376           376      376
# 08      399  399  399           399      399
# 09      377  377  377           377      377
# 10      377  377  377           377      377
# 11      104  104  104           104      104
# 12      266  266  266           266      266
# 13      265  265  265           265      265
# 14      271  271  271           271      271
# 15      264  264  264           264      264
# 16      223  223  223           223      223
# 17      184  184  184           184      184
# 18      200  200  200           200      200
# 19      209  209  209           209      209
# 20      191  191  191           191      191
# 21      213  213  213           213      213
# 22      190  190  190           190      190
# 23      189  189  189           189      189

# %% [markdown]
# # for the IP: 89.111.92.21

# %%
data_for_requests_for_91_209_155_250 = haproxy[haproxy['ip']=="89.111.92.21"]
data_for_requests_for_91_209_155_250 = data_for_requests_for_91_209_155_250[data_for_requests_for_91_209_155_250["Day"] == 17]
data_for_requests_for_91_209_155_250 = data_for_requests_for_91_209_155_250[data_for_requests_for_91_209_155_250["sftp_channel"] == "sftp/sftp-5"]

# %%
data_for_requests_for_91_209_155_250.groupby(["time"]).count()
# Out:
#       Month   Day    ip  sftp_channel  minutes
# time
# 03        8     8     8             8        8
# 04        8     8     8             8        8
# 05       13    13    13            13       13
# 06      987   987   987           987      987
# 07     2234  2234  2234          2234     2234
# 08     2280  2280  2280          2280     2280
# 09     1045  1045  1045          1045     1045
# 10      114   114   114           114      114

# %% [markdown]
# # # for the IP: 5.32.184.10

# %%
data_for_requests_for_5_32_184_10 = haproxy[haproxy['ip']=="5.32.184.10"]
data_for_requests_for_5_32_184_10 = data_for_requests_for_5_32_184_10[data_for_requests_for_5_32_184_10["Day"] == 17]
data_for_requests_for_5_32_184_10 = data_for_requests_for_5_32_184_10[data_for_requests_for_5_32_184_10["sftp_channel"] == "sftp/sftp-5"]

# %%
data_for_requests_for_5_32_184_10.groupby(["time"]).count()
# Out:
#       Month  Day   ip  sftp_channel  minutes
# time
# 03       59   59   59            59       59
# 04       85   85   85            85       85
# 05       95   95   95            95       95
# 06      374  374  374           374      374
# 07      535  535  535           535      535
# 08      535  535  535           535      535
# 09      533  533  533           533      533
# 10      535  535  535           535      535
# 11       85   85   85            85       85
# 12      180  180  180           180      180
# 13      176  176  176           176      176
# 14      183  183  183           183      183
# 15      158  158  158           158      158
# 16      158  158  158           158      158
# 17      120  120  120           120      120
# 18      122  122  122           122      122
# 19      134  134  134           134      134
# 20      123  123  123           123      123
# 21      135  135  135           135      135
# 22      137  137  137           137      137
# 23      136  136  136           136      136

# %% [markdown]
# # it's clearly visible that seps was sending 3-5 k requests in a short time while we are able to see data distribution is normal for the other IPs

# %% [markdown]
# # Lets check the minutes of the huge requests for 6 AM for the IP: 213.151.236.158

# %%
data_for_requests_for_213_151_236_158 = haproxy[haproxy['ip']=="213.151.236.158"]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['Day']==17]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['sftp_channel']=="sftp/sftp-5"]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['time']=='06']

# %%
data_for_requests_for_213_151_236_158.groupby(['minutes']).count()
# Out:
#          Month  Day  time  ip  sftp_channel
# minutes
# 02           2    2     2   2             2
# 03           1    1     1   1             1
# 04           2    2     2   2             2
# 05           2    2     2   2             2
# 07           2    2     2   2             2
# 08           2    2     2   2             2
# 09           1    1     1   1             1
# 11           1    1     1   1             1
# 12           1    1     1   1             1
# 13           2    2     2   2             2
# 14           2    2     2   2             2
# 15           1    1     1   1             1
# 17           1    1     1   1             1
# 18           2    2     2   2             2
# 19           2    2     2   2             2
# 20          67   67    67  67            67
# 21          95   95    95  95            95
# 22          95   95    95  95            95
# 23          96   96    96  96            96
# 24          94   94    94  94            94
# 25          87   87    87  87            87
# 26          95   95    95  95            95
# 27          95   95    95  95            95
# 28          92   92    92  92            92
# 29          91   91    91  91            91
# 30          94   94    94  94            94
# 31          91   91    91  91            91
# 32          94   94    94  94            94
# 33          81   81    81  81            81
# 34          93   93    93  93            93
# 35          94   94    94  94            94
# 36          93   93    93  93            93
# 37          91   91    91  91            91
# 38          91   91    91  91            91
# 39          92   92    92  92            92
# 40          92   92    92  92            92
# 41          93   93    93  93            93
# 42          92   92    92  92            92
# 43          82   82    82  82            82
# 44          89   89    89  89            89
# 45          90   90    90  90            90
# 46          89   89    89  89            89
# 47          92   92    92  92            92
# 48          92   92    92  92            92
# 49          92   92    92  92            92
# 50          91   91    91  91            91
# 51          87   87    87  87            87
# 52          91   91    91  91            91
# 53          89   89    89  89            89
# 54          89   89    89  89            89
# 55          88   88    88  88            88
# 56          89   89    89  89            89
# 57          85   85    85  85            85
# 58          91   91    91  91            91
# 59          90   90    90  90            90

# %% [markdown]
# # Lets check the minutes of the huge requests for 7 AM for the IP: 213.151.236.158

# %%
data_for_requests_for_213_151_236_158 = haproxy[haproxy['ip']=="213.151.236.158"]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['Day']==17]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['sftp_channel']=="sftp/sftp-5"]
data_for_requests_for_213_151_236_158 = data_for_requests_for_213_151_236_158[data_for_requests_for_213_151_236_158['time']=='07']

# %%
data_for_requests_for_213_151_236_158.groupby(['minutes']).count()
# Out:
#          Month  Day  time  ip  sftp_channel
# minutes
# 00          87   87    87  87            87
# 01          85   85    85  85            85
# 02          87   87    87  87            87
# 03          88   88    88  88            88
# 04          87   87    87  87            87
# 05          85   85    85  85            85
# 06          86   86    86  86            86
# 07          87   87    87  87            87
# 08          88   88    88  88            88
# 09          85   85    85  85            85
# 10          88   88    88  88            88
# 11          85   85    85  85            85
# 12          89   89    89  89            89
# 13          86   86    86  86            86
# 14          88   88    88  88            88
# 15          84   84    84  84            84
# 16          80   80    80  80            80
# 17          83   83    83  83            83
# 18          86   86    86  86            86
# 19          81   81    81  81            81
# 20          77   77    77  77            77
# 21          82   82    82  82            82
# 22          80   80    80  80            80
# 23          85   85    85  85            85
# 24          86   86    86  86            86
# 25          88   88    88  88            88
# 26          85   85    85  85            85
# 27          86   86    86  86            86
# 28          84   84    84  84            84
# 29          85   85    85  85            85
# 30          80   80    80  80            80
# 31          85   85    85  85            85
# 32          85   85    85  85            85
# 33          83   83    83  83            83
# 34          85   85    85  85            85
# 35          86   86    86  86            86
# 36          88   88    88  88            88
# 37          82   82    82  82            82
# 38          85   85    85  85            85
# 39          84   84    84  84            84
# 40          81   81    81  81            81
# 41          84   84    84  84            84
# 42          86   86    86  86            86
# 43          86   86    86  86            86
# 44          84   84    84  84            84
# 45          84   84    84  84            84
# 46          83   83    83  83            83
# 47          84   84    84  84            84
# 48          84   84    84  84            84
# 49          80   80    80  80            80
# 50          85   85    85  85            85
# 51          76   76    76  76            76
# 52          81   81    81  81            81
# 53          86   86    86  86            86
# 54          83   83    83  83            83
# 55          81   81    81  81            81
# 56          83   83    83  83            83
# 57          80   80    80  80            80
# 58          81   81    81  81            81
# 59          59   59    59  59            59

# %% [markdown]
# # For 89.111.92.21 For 6AM

# %%
data_for_requests_for_89_111_92_21 = haproxy[haproxy['ip']=="89.111.92.21"]
data_for_requests_for_89_111_92_21 = data_for_requests_for_89_111_92_21[data_for_requests_for_89_111_92_21['Day']==17]
data_for_requests_for_89_111_92_21 = data_for_requests_for_89_111_92_21[data_for_requests_for_89_111_92_21['sftp_channel']=="sftp/sftp-5"]
data_for_requests_for_89_111_92_21 = data_for_requests_for_89_111_92_21[data_for_requests_for_89_111_92_21['time']=='06']

# %%
data_for_requests_for_89_111_92_21.groupby(['minutes']).count()
# Out:
#          Month  Day  time  ip  sftp_channel
# minutes
# 00           8    8     8   8             8
# 30           4    4     4   4             4
# 35          48   48    48  48            48
# 36          42   42    42  42            42
# 37          37   37    37  37            37
# 38          47   47    47  47            47
# 39          36   36    36  36            36
# 40          40   40    40  40            40
# 41          45   45    45  45            45
# 42          44   44    44  44            44
# 43          36   36    36  36            36
# 44          36   36    36  36            36
# 45          41   41    41  41            41
# 46          41   41    41  41            41
# 47          35   35    35  35            35
# 48          44   44    44  44            44
# 49          43   43    43  43            43
# 50          42   42    42  42            42
# 51          36   36    36  36            36
# 52          36   36    36  36            36
# 53          39   39    39  39            39
# 54          38   38    38  38            38
# 55          28   28    28  28            28
# 56          33   33    33  33            33
# 57          36   36    36  36            36
# 58          36   36    36  36            36
# 59          36   36    36  36            36

# %% [markdown]
# # For 89.111.92.21 For 7AM

# %%
data_for_requests_for_89_111_92_21 = haproxy[haproxy['ip']=="89.111.92.21"]
data_for_requests_for_89_111_92_21 = data_for_requests_for_89_111_92_21[data_for_requests_for_89_111_92_21['Day']==17]
data_for_requests_for_89_111_92_21 = data_for_requests_for_89_111_92_21[data_for_requests_for_89_111_92_21['sftp_channel']=="sftp/sftp-5"]
data_for_requests_for_89_111_92_21 = data_for_requests_for_89_111_92_21[data_for_requests_for_89_111_92_21['time']=='07']

# %%
data_for_requests_for_89_111_92_21.groupby(['minutes']).count()
# Out:
#          Month  Day  time  ip  sftp_channel
# minutes
# 00          40   40    40  40            40
# 01          38   38    38  38            38
# 02          35   35    35  35            35
# 03          39   39    39  39            39
# 04          48   48    48  48            48
# 05          37   37    37  37            37
# 06          39   39    39  39            39
# 07          30   30    30  30            30
# 08          40   40    40  40            40
# 09          38   38    38  38            38
# 10          36   36    36  36            36
# 11          35   35    35  35            35
# 12          38   38    38  38            38
# 13          38   38    38  38            38
# 14          36   36    36  36            36
# 15          61   61    61  61            61
# 16          40   40    40  40            40
# 17          39   39    39  39            39
# 18          17   17    17  17            17
# 19          40   40    40  40            40
# 20          30   30    30  30            30
# 21          27   27    27  27            27
# 22          32   32    32  32            32
# 23          36   36    36  36            36
# 24          34   34    34  34            34
# 25          36   36    36  36            36
# 26          33   33    33  33            33
# 27          36   36    36  36            36
# 28          36   36    36  36            36
# 29          35   35    35  35            35
# 30          29   29    29  29            29
# 31          35   35    35  35            35
# 32          36   36    36  36            36
# 33          36   36    36  36            36
# 34          44   44    44  44            44
# 35          37   37    37  37            37
# 36          39   39    39  39            39
# 37          36   36    36  36            36
# 38          53   53    53  53            53
# 39          34   34    34  34            34
# 40          44   44    44  44            44
# 41          39   39    39  39            39
# 42          36   36    36  36            36
# 43          38   38    38  38            38
# 44          36   36    36  36            36
# 45          57   57    57  57            57
# 46          36   36    36  36            36
# 47          38   38    38  38            38
# 48          36   36    36  36            36
# 49          39   39    39  39            39
# 50          35   35    35  35            35
# 51          35   35    35  35            35
# 52          36   36    36  36            36
# 53          40   40    40  40            40
# 54          35   35    35  35            35
# 55          36   36    36  36            36
# 56          36   36    36  36            36
# 57          34   34    34  34            34
# 58          34   34    34  34            34
# 59          36   36    36  36            36

# %%
! jupyter nbconvert --to html HAPROXY_LOG_analytics.ipynb
# Out:
# [NbConvertApp] Converting notebook HAPROXY_LOG_analytics.ipynb to html
# [NbConvertApp] Writing 728994 bytes to HAPROXY_LOG_analytics.html
